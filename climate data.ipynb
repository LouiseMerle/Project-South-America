# %%
#Montevideo

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url = 'https://www.klimaatinfo.nl/verenigde-staten-van-amerika/arizona/yuma.htm'

html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

table = soup.find_all('table', {'id': 'AutoNumber3'})[0]

rows = table.find_all('tr')
rows

rows_2 = [row.find_all('td') for row in rows]


text = [[x.text for x in row] for row in rows_2]

colnames = ['month', 'avg_max_temp', 'avg_min_temp', 'hours_of_sun', 'rain_days_per_month', 'avg_rain', 'avg_sea_temp']

climate_raw = pd.DataFrame(text, columns = colnames)

climate_raw_2 = climate_raw.drop(climate_raw.index[[0,1,14]])
climate_raw_2

del climate_raw_2['avg_rain']
climate_raw_2


#climate_raw['month'] = climate_raw['month'].map(lambda x: x.lstrip('\n'))

#climate_raw['avg max temp'] = climate_raw['avg max temp'].map(lambda x: x.lstrip('\r\r\n'))
# Out:
#           month              avg_max_temp              avg_min_temp  \
# 2     \njanuari  \r\n\r\n              20   \r\n\r\n              7
# 3    \nfebruari  \r\n\r\n              24   \r\n\r\n              8
# 4       \nmaart  \r\n\r\n              26  \r\n\r\n              10
# 5       \napril  \r\n\r\n              30  \r\n\r\n              14
# 6         \nmei  \r\n\r\n              35  \r\n\r\n              18
# 7        \njuni  \r\n\r\n              40  \r\n\r\n              22
# 8        \njuli  \r\n\r\n              42  \r\n\r\n              27
# 9    \naugustus  \r\n\r\n              41  \r\n\r\n              26
# 10  \nseptember  \r\n\r\n              38  \r\n\r\n              23
# 11    \noktober  \r\n\r\n              33  \r\n\r\n              17
# 12   \nnovember  \r\n\r\n              25  \r\n\r\n              11
# 13   \ndecember  \r\n\r\n              20   \r\n\r\n              7
#
#                 hours_of_sun      rain_days_per_month  \
# ...

# %%
climate_raw_2['month'] = climate_raw_2['month'].map(lambda x: x.lstrip('\n'))
climate_raw_2['avg_max_temp'] = climate_raw_2['avg_max_temp'].map(lambda x: x.lstrip('\r\r\n'))
climate_raw_2['avg_min_temp'] = climate_raw_2['avg_min_temp'].map(lambda x: x.lstrip('\r\r\n'))
climate_raw_2['hours_of_sun'] = climate_raw_2['hours_of_sun'].map(lambda x: x.lstrip('\r\r\n'))
climate_raw_2['rain_days_per_month'] = climate_raw_2['rain_days_per_month'].map(lambda x: x.lstrip('\r\r\n'))
climate_raw_2['avg_sea_temp'] = climate_raw_2['avg_sea_temp'].map(lambda x: x.lstrip('\r\r\n'))
climate_raw_2
# Out:
#         month      avg_max_temp      avg_min_temp      hours_of_sun  \
# 2     januari                20                 7                 9
# 3    februari                24                 8                10
# 4       maart                26                10                11
# 5       april                30                14                12
# 6         mei                35                18                13
# 7        juni                40                22                14
# 8        juli                42                27                13
# 9    augustus                41                26                12
# 10  september                38                23                11
# 11    oktober                33                17                10
# 12   november                25                11                 9
# 13   december                20                 7                 8
#
#    rain_days_per_month          avg_sea_temp
# ...

# %%
climate_raw_2.to_csv('Mexicali.csv')

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/louise/Documents/ironhack/project week 3'

# %%
montevideo = pd.read_csv('montevideo.csv')
montevideo
temp = montevideo[(montevideo.avg_max_temp >= 25) & (montevideo.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_montevideo = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_montevideo['City'] = 'Montevideo'
sun_montevideo
# Out:
# /Users/louise/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#    Unnamed: 0    month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 0           2  januari            28            17             9
#
#    rain_days_per_month  avg_sea_temp        City
# 0                   10            22  Montevideo

# %%
lima = pd.read_csv('Lima.csv')
lima
temp = lima[(lima.avg_max_temp >= 25) & (lima.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_lima = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_lima['City'] = 'Lima'
sun_lima
# Out:
#    Unnamed: 0  month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 2           4  maart            26            19             7
#
#    rain_days_per_month  avg_sea_temp  City
# 2                    3            22  Lima

# %%
arequipa = pd.read_csv('Arequipa.csv')
arequipa
temp = arequipa[(arequipa.avg_max_temp >= 23) & (arequipa.avg_max_temp <= 30)]
temp

rain_arequipa = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
rain_arequipa
rain_arequipa['City'] = 'Arequipa'
rain_arequipa
# Out:
# /Users/louise/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Unnamed: 0  month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 3           5  april            23             7             9
#
#    rain_days_per_month          avg_sea_temp      City
# 3                    2                n.v.t.  Arequipa

# %%
asuncion = pd.read_csv('Asuncion.csv')
asuncion
temp = asuncion[(asuncion.avg_max_temp >= 25) & (asuncion.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_asuncion = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_asuncion['City'] = 'Asuncion'
sun_asuncion
# Out:
#    Unnamed: 0 month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 4           6   mei            25            16             7
#
#    rain_days_per_month          avg_sea_temp      City
# 4                    6                n.v.t.  Asuncion

# %%
oaxaca = pd.read_csv('Oaxaca.csv')
oaxaca
temp = oaxaca[(oaxaca.avg_max_temp >= 25) & (oaxaca.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_oaxaca = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_oaxaca['City'] = 'Oaxaca'
sun_oaxaca
# Out:
#    Unnamed: 0     month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 1           3  februari            27             8             8
#
#    rain_days_per_month          avg_sea_temp    City
# 1                    2                n.v.t.  Oaxaca

# %%
puebla = pd.read_csv('Puebla.csv')
puebla
temp = puebla[(puebla.avg_max_temp >= 25) & (puebla.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_puebla = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_puebla['City'] = 'Puebla'
sun_puebla
# Out:
#    Unnamed: 0  month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 2           4  maart            25             9             8
#
#    rain_days_per_month          avg_sea_temp    City
# 2                    2                n.v.t.  Puebla

# %%
hermosillo = pd.read_csv('Hermosillo.csv')
hermosillo
temp = hermosillo[(hermosillo.avg_max_temp >= 25) & (hermosillo.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_hermosillo = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_hermosillo['City'] = 'Hermosillo'
sun_hermosillo
# Out:
#    Unnamed: 0  month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 3           5  april            27             9             9
#
#    rain_days_per_month          avg_sea_temp        City
# 3                    1                n.v.t.  Hermosillo

# %%
puerto_vallarta = pd.read_csv('Puerto-Vallarta.csv')
puerto_vallarta
temp = puerto_vallarta[(puerto_vallarta.avg_max_temp >= 25) & (puerto_vallarta.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_puerto_vallarta = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_puerto_vallarta['City'] = 'Puerto Vallarta'

sun_puerto_vallarta
# Out:
# /Users/louise/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#    Unnamed: 0  month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 3           5  april            31            22             8
#
#    rain_days_per_month  avg_sea_temp             City
# 3                    5            27  Puerto Vallarta

# %%
mexicali = pd.read_csv('Mexicali.csv')
mexicali
temp = mexicali[(mexicali.avg_max_temp >= 25) & (mexicali.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_mexicali = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_mexicali['City'] = 'Mexicali'
sun_mexicali
# Out:
#    Unnamed: 0  month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 3           5  april            30            14            12
#
#    rain_days_per_month          avg_sea_temp      City
# 3                    2                n.v.t.  Mexicali

# %%
merida = pd.read_csv('Merida.csv')
merida
temp = merida[(merida.avg_max_temp >= 25) & (merida.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_merida = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_merida['City'] = 'Merida'
sun_merida
# Out:
#    Unnamed: 0     month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 1           3  februari            30            18             7
#
#    rain_days_per_month          avg_sea_temp    City
# 1                    3                n.v.t.  Merida

# %%
san_miguel_de_allende = pd.read_csv('San_Miguel_de_Allende.csv')
san_miguel_de_allende
temp = san_miguel_de_allende[(san_miguel_de_allende.avg_max_temp >= 25) & (san_miguel_de_allende.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_san_miguel_de_allende = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_san_miguel_de_allende['City'] = 'San Miguel de Allende'

sun_san_miguel_de_allende
# Out:
# /Users/louise/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#    Unnamed: 0  month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 2           4  maart            28            10             7
#
#    rain_days_per_month          avg_sea_temp                   City
# 2                    2                n.v.t.  San Miguel de Allende

# %%
queretaro = pd.read_csv('Queretaro.csv')
queretaro
temp = queretaro[(queretaro.avg_max_temp >= 25) & (queretaro.avg_max_temp <= 32)]
rain = temp[temp.rain_days_per_month == temp.rain_days_per_month.min()]
sun = rain[rain.hours_of_sun == rain.hours_of_sun.max()]
sun_queretaro = sun[sun.avg_min_temp == sun.avg_min_temp.max()]
sun_queretaro['City'] = 'Queretaro'
sun_queretaro
# Out:
#    Unnamed: 0  month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 2           4  maart            26             7             7
#
#    rain_days_per_month          avg_sea_temp       City
# 2                    1                n.v.t.  Queretaro

# %%
frames = [sun_montevideo, sun_lima, rain_arequipa, sun_asuncion, sun_oaxaca, sun_puebla, sun_hermosillo, sun_puerto_vallarta, sun_mexicali, sun_merida, sun_san_miguel_de_allende, sun_queretaro]

# %%
total_bottom = pd.concat(frames)

# %%
total_bottom
# Out:
#    Unnamed: 0     month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 0           2   januari            28            17             9
# 2           4     maart            26            19             7
# 3           5     april            23             7             9
# 4           6       mei            25            16             7
# 1           3  februari            27             8             8
# 2           4     maart            25             9             8
# 3           5     april            27             9             9
# 3           5     april            31            22             8
# 3           5     april            30            14            12
# 1           3  februari            30            18             7
# 2           4     maart            28            10             7
# 2           4     maart            26             7             7
#
#    rain_days_per_month          avg_sea_temp                   City
# ...

# %%
total_bottom.to_csv('total_bottom.csv')

# %%
total_top = pd.read_csv('total_top.csv')

# %%
total_bottom
# Out:
#       month  avg_max_temp  avg_min_temp  hours_of_sun  rain_days_per_month  \
# 0   januari            28            17             9                   10
# 2     maart            26            19             7                    3
# 3     april            23             7             9                    2
# 4       mei            25            16             7                    6
# 1  februari            27             8             8                    2
# 2     maart            25             9             8                    2
# 3     april            27             9             9                    1
# 3     april            31            22             8                    5
# 3     april            30            14            12                    2
# 1  februari            30            18             7                    3
# 2     maart            28            10             7                    2
# ...

# %%
total_top
# Out:
#        month  avg_max_temp  avg_min_temp  hours_of_sun  rain_days_per_month  \
# 0    januari            26            14            11                    2
# 1    oktober            26            12             8                    7
# 2  september            25             9             7                    5
# 3   februari            32            25             7                    4
# 4    oktober            32            19             3                    0
# 5   augustus            21             2             6                    8
# 6    oktober            32            19             3                    0
# 7   augustus            21             2             6                    8
# 8      april            32            21             8                    3
#
#            avg_sea_temp        City
# 0                n.v.t.     Ushuaia
# 1                n.v.t.     Cordoba
# 2                n.v.t.  Cochabamba
# 3                    28  Cochabamba
# ...

# %%
frames = [total_top, total_bottom]

# %%
total = pd.concat(frames)

# %%
total
# Out:
#        month  avg_max_temp  avg_min_temp  hours_of_sun  rain_days_per_month  \
# 0    januari            26            14            11                    2
# 1    oktober            26            12             8                    7
# 2  september            25             9             7                    5
# 3   februari            32            25             7                    4
# 4    oktober            32            19             3                    0
# 5   augustus            21             2             6                    8
# 6    oktober            32            19             3                    0
# 7   augustus            21             2             6                    8
# 8      april            32            21             8                    3
# 0    januari            28            17             9                   10
# 2      maart            26            19             7                    3
# ...

# %%
col_order = ['City', 'month', 'avg_max_temp', 'avg_min_temp', 'hours_of_sun', 'rain_days_per_month', 'avg_sea_temp']

# %%
total = total[col_order]

# %%
total
# Out:
#                     City      month  avg_max_temp  avg_min_temp  hours_of_sun  \
# 0                Ushuaia    januari            26            14            11
# 1                Cordoba    oktober            26            12             8
# 2             Cochabamba  september            25             9             7
# 3             Cochabamba   februari            32            25             7
# 4              Montanita    oktober            32            19             3
# 5                  Quito   augustus            21             2             6
# 6              Guayaquil    oktober            32            19             3
# 7                 Cuenca   augustus            21             2             6
# 8                 Cancun      april            32            21             8
# 0             Montevideo    januari            28            17             9
# 2                   Lima      maart            26            19             7
# ...

# %%
go there in thursday 
return on moneday
