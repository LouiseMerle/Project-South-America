# %%
import pandas as pd
import json
import os
import requests



os.getcwd()
# Out:
# '/Users/louise/Documents/ironhack/cities'

# %%
data = json.load(open('sao-paulo.json'))
sao_paulo = pd.DataFrame(data["categories"])


sao_paulo2 = sao_paulo.transpose()

sao_paulo2
# Out:
#                        0               1         2                3  \
# color            #f3c32c         #f3d630   #f4eb33          #d2ed31
# name             Housing  Cost of Living  Startups  Venture Capital
# score_out_of_10    8.316           7.823    6.6225            4.253
#
#                                    4        5                 6        7  \
# color                        #7adc29  #36cc24           #19ad51  #0d6999
# name             Travel Connectivity  Commute  Business Freedom   Safety
# score_out_of_10               2.2655    4.412             2.781   5.2955
#
#                           8          9                     10       11  \
# color               #051fa5    #150e78                #3d14a4  #5c14a1
# name             Healthcare  Education  Environmental Quality  Economy
# score_out_of_10     5.46233      1.104                 2.6535    2.187
#
#                        12               13                 14         15  \
# ...

# %%
sao_paulo2.dtypes

col_names = ['Housing', 'Cost of Living', 'Startups', 'Venture Capital', 'Travel Connectivity', 'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Education', 'Environmental Quality', 'Economy', 'Taxation', 'Internet Access', 'Leisure & Culture', 'Tolerance', 'Outdoors']
sao_paulo2.columns = [col_names]

sao_paulo2

sao_paulo3 = sao_paulo2.drop(sao_paulo2.index[0])
sao_paulo = sao_paulo3.drop(sao_paulo3.index[0])
sao_paulo

#sao_paulo4 = sao_paulo[['Housing', 'Cost of Living', 'Startups', 'Venture Capital', 'Travel Connectivity', 'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Education', 'Environmental Quality', 'Economy', 'Taxation', 'Internet Access', 'Leisure & Culture', 'Tolerance', 'Outdoors']] = sao_paulo[['Housing', 'Cost of Living', 'Startups', 'Venture Capital', 'Travel Connectivity', 'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Education', 'Environmental Quality', 'Economy', 'Taxation', 'Internet Access', 'Leisure & Culture', 'Tolerance', 'Outdoors']].astype(int)

sao_paulo['Housing'] = sao_paulo.Housing.astype(float)

print(sao_paulo)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-ebc750423d15> in <module>
#      12 #sao_paulo4 = sao_paulo[['Housing', 'Cost of Living', 'Startups', 'Venture Capital', 'Travel Connectivity', 'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Education', 'Environmental Quality', 'Economy', 'Taxation', 'Internet Access', 'Leisure & Culture', 'Tolerance', 'Outdoors']] = sao_paulo[['Housing', 'Cost of Living', 'Startups', 'Venture Capital', 'Travel Connectivity', 'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Education', 'Environmental Quality', 'Economy', 'Taxation', 'Internet Access', 'Leisure & Culture', 'Tolerance', 'Outdoors']].astype(int)
#      13
# ---> 14 sao_paulo['Housing'] = sao_paulo.Housing.astype(float)
#      15
#      16 print(sao_paulo)
#
# ...

# %%
sao_paulo.dtypes
# Out:
# Housing                  object
# Cost of Living           object
# Startups                 object
# Venture Capital          object
# Travel Connectivity      object
# Commute                  object
# Business Freedom         object
# Safety                   object
# Healthcare               object
# Education                object
# Environmental Quality    object
# Economy                  object
# Taxation                 object
# Internet Access          object
# Leisure & Culture        object
# Tolerance                object
# Outdoors                 object
# dtype: object

# %%
col_names = ['Categories', 'Sao Paulo']
sao_paulo.columns = [col_names]

# %%
sao_paulo
# Out:
#                Categories Sao Paulo
# 0                 Housing  8.316000
# 1          Cost of Living  7.823000
# 2                Startups  6.622500
# 3         Venture Capital  4.253000
# 4     Travel Connectivity  2.265500
# 5                 Commute  4.412000
# 6        Business Freedom  2.781000
# 7                  Safety  5.295500
# 8              Healthcare  5.462333
# 9               Education  1.104000
# 10  Environmental Quality  2.653500
# 11                Economy  2.187000
# 12               Taxation  2.852500
# 13        Internet Access  3.389500
# 14      Leisure & Culture  8.789500
# 15              Tolerance  6.895500
# 16               Outdoors  7.077500

# %%
data = json.load(open('caracas.json'))
caracas = pd.DataFrame(data["categories"])

del caracas['color']

col_names = ['Categories2', 'Caracas']
caracas.columns = [col_names]

caracas



#jsdkfhsjdkf
# Out:
#               Categories2   Caracas
# 0                 Housing  4.902500
# 1          Cost of Living  9.820000
# 2                Startups  3.053500
# 3         Venture Capital  0.000000
# 4     Travel Connectivity  1.323500
# 5                 Commute  4.544250
# 6        Business Freedom  1.000000
# 7                  Safety  5.221000
# 8              Healthcare  4.241333
# 9               Education  0.000000
# 10  Environmental Quality  2.272500
# 11                Economy  1.978000
# 12               Taxation  4.180000
# 13        Internet Access  1.641500
# 14      Leisure & Culture  4.380000
# 15              Tolerance  4.550500
# 16               Outdoors  4.098500

# %%
data = json.load(open('santiago.json'))
santiago = pd.DataFrame(data["categories"])

del santiago['color']

col_names = ['Categories4', 'Santiago']
santiago.columns = [col_names]

santiago
# Out:
#               Categories4  Santiago
# 0                 Housing  8.381500
# 1          Cost of Living  7.237000
# 2                Startups  6.230500
# 3         Venture Capital  1.000000
# 4     Travel Connectivity  2.535500
# 5                 Commute  5.551000
# 6        Business Freedom  7.765000
# 7                  Safety  6.964500
# 8              Healthcare  7.231667
# 9               Education  2.641500
# 10  Environmental Quality  4.528000
# 11                Economy  3.725000
# 12               Taxation  8.929500
# 13        Internet Access  1.000000
# 14      Leisure & Culture  7.556000
# 15              Tolerance  7.171500
# 16               Outdoors  5.500000

# %%
data = json.load(open('bogota.json'))
bogota = pd.DataFrame(data["categories"])

del bogota['color']

col_names = ['Categories20', 'Bogota']
bogota.columns = [col_names]

bogota
# Out:
#              Categories20    Bogota
# 0                 Housing  9.027500
# 1          Cost of Living  9.080000
# 2                Startups  5.708500
# 3         Venture Capital  1.259000
# 4     Travel Connectivity  1.889000
# 5                 Commute  4.964000
# 6        Business Freedom  6.348667
# 7                  Safety  6.222000
# 8              Healthcare  5.139000
# 9               Education  1.534000
# 10  Environmental Quality  4.347500
# 11                Economy  4.594500
# 12               Taxation  1.851500
# 13        Internet Access  2.976000
# 14      Leisure & Culture  6.215000
# 15              Tolerance  8.555500
# 16               Outdoors  7.477000

# %%
data = json.load(open('buenos_aires.json'))
buenos_aires = pd.DataFrame(data["categories"])

del buenos_aires['color']

col_names = ['Categories21', 'Buenos Aires']
buenos_aires.columns = [col_names]

buenos_aires
# Out:
#              Categories21 Buenos Aires
# 0                 Housing     8.812000
# 1          Cost of Living     7.764000
# 2                Startups     4.673000
# 3         Venture Capital     2.310000
# 4     Travel Connectivity     3.770000
# 5                 Commute     4.923500
# 6        Business Freedom     4.045333
# 7                  Safety     6.039500
# 8              Healthcare     6.106667
# 9               Education     1.422000
# 10  Environmental Quality     4.869000
# 11                Economy     2.884000
# 12               Taxation     1.568000
# 13        Internet Access     1.527500
# 14      Leisure & Culture     7.673500
# 15              Tolerance     8.584000
# 16               Outdoors     4.535500

# %%
data = json.load(open('curitiba.json'))
curitiba = pd.DataFrame(data["categories"])

del curitiba['color']

col_names = ['Categories22', 'Curitiba']
curitiba.columns = [col_names]

curitiba
# Out:
#              Categories22  Curitiba
# 0                 Housing  9.429500
# 1          Cost of Living  8.433000
# 2                Startups  2.912000
# 3         Venture Capital  2.148000
# 4     Travel Connectivity  0.890000
# 5                 Commute  4.950250
# 6        Business Freedom  2.781000
# 7                  Safety  5.946500
# 8              Healthcare  5.579333
# 9               Education  1.016500
# 10  Environmental Quality  7.757250
# 11                Economy  2.187000
# 12               Taxation  2.852500
# 13        Internet Access  3.142000
# 14      Leisure & Culture  7.187500
# 15              Tolerance  7.848000
# 16               Outdoors  2.665500

# %%
'''
response = requests.get('https://api.teleport.org/api/urban_areas/slug%3Alima/scores/')
results = response.json()
print(results)

lima = pd.DataFrame.from_dict(results, orient='columns')

del lima['color']

col_names = ['Categories23', 'Lima']
lima.columns = [col_names]

lim
'''


#df = pd.DataFrame.from_dict(data, orient='columns')
# Out:
# "\nresponse = requests.get('https://api.teleport.org/api/urban_areas/slug%3Alima/scores/')\nresults = response.json()\nprint(results)\n\nlima = pd.DataFrame.from_dict(results, orient='columns')\n\ndel lima['color']\n\ncol_names = ['Categories23', 'Lima']\nlima.columns = [col_names]\n\nlim\n"

# %%
data = json.load(open('rio_de_janeiro.json'))
rio_de_janeiro = pd.DataFrame(data["categories"])

del rio_de_janeiro['color']

col_names = ['Categories5', 'Rio de Janeiro']
rio_de_janeiro.columns = [col_names]

rio_de_janeiro
# Out:
#               Categories5 Rio de Janeiro
# 0                 Housing       8.320000
# 1          Cost of Living       7.751000
# 2                Startups       4.823000
# 3         Venture Capital       2.414000
# 4     Travel Connectivity       1.493000
# 5                 Commute       4.553250
# 6        Business Freedom       4.036667
# 7                  Safety       5.295500
# 8              Healthcare       4.996667
# 9               Education       1.017500
# 10  Environmental Quality       3.322750
# 11                Economy       2.187000
# 12               Taxation       2.845500
# 13        Internet Access       2.338000
# 14      Leisure & Culture       8.667500
# 15              Tolerance       5.771500
# 16               Outdoors       6.152000

# %%
data = json.load(open('quito.json'))
quito = pd.DataFrame(data["categories"])

del quito['color']

col_names = ['Categories6', 'Quito']
quito.columns = [col_names]

quito



#jsdsa
# Out:
#               Categories6     Quito
# 0                 Housing  9.016500
# 1          Cost of Living  7.822000
# 2                Startups  2.857500
# 3         Venture Capital  0.000000
# 4     Travel Connectivity  0.890000
# 5                 Commute  4.789250
# 6        Business Freedom  3.021333
# 7                  Safety  6.969000
# 8              Healthcare  5.324000
# 9               Education  0.000000
# 10  Environmental Quality  4.176250
# 11                Economy  3.885500
# 12               Taxation  7.514000
# 13        Internet Access  3.481500
# 14      Leisure & Culture  4.801500
# 15              Tolerance  8.826500
# 16               Outdoors  5.500000

# %%
data = json.load(open('porto_alegre.json'))
porto_alegre = pd.DataFrame(data["categories"])

del porto_alegre['color']

col_names = ['Categories7', 'Porto Alegre']
porto_alegre.columns = [col_names]

porto_alegre
# Out:
#               Categories7 Porto Alegre
# 0                 Housing     9.221000
# 1          Cost of Living     8.120000
# 2                Startups     2.670500
# 3         Venture Capital     0.000000
# 4     Travel Connectivity     0.965500
# 5                 Commute     5.105000
# 6        Business Freedom     2.781000
# 7                  Safety     5.295500
# 8              Healthcare     5.499667
# 9               Education     1.017000
# 10  Environmental Quality     4.139750
# 11                Economy     2.187000
# 12               Taxation     2.852500
# 13        Internet Access     2.196000
# 14      Leisure & Culture     7.703500
# 15              Tolerance     7.448000
# 16               Outdoors     4.922500

# %%
data = json.load(open('montevideo.json'))
montevideo = pd.DataFrame(data["categories"])

del montevideo['color']

col_names = ['Categories8', 'Montevideo']
montevideo.columns = [col_names]

montevideo

#asdjhakjds
# Out:
#               Categories8 Montevideo
# 0                 Housing   8.183000
# 1          Cost of Living   6.197000
# 2                Startups   2.863000
# 3         Venture Capital   2.205000
# 4     Travel Connectivity   1.183000
# 5                 Commute   5.288000
# 6        Business Freedom   7.944000
# 7                  Safety   5.973500
# 8              Healthcare   6.364667
# 9               Education   1.690000
# 10  Environmental Quality   4.545000
# 11                Economy   4.416000
# 12               Taxation   4.828500
# 13        Internet Access   2.178500
# 14      Leisure & Culture   4.946500
# 15              Tolerance   9.710000
# 16               Outdoors   5.178500

# %%
data = json.load(open('medellin.json'))
medellin = pd.DataFrame(data["categories"])

del medellin['color']

col_names = ['Categories9', 'Medellin']
medellin.columns = [col_names]

medellin


#asdjhakjds
# Out:
#               Categories9  Medellin
# 0                 Housing  9.231500
# 1          Cost of Living  9.315000
# 2                Startups  4.618000
# 3         Venture Capital  0.000000
# 4     Travel Connectivity  0.928000
# 5                 Commute  5.354500
# 6        Business Freedom  6.348667
# 7                  Safety  7.477000
# 8              Healthcare  5.452333
# 9               Education  1.531000
# 10  Environmental Quality  6.170750
# 11                Economy  4.594500
# 12               Taxation  1.851500
# 13        Internet Access  4.148500
# 14      Leisure & Culture  5.029000
# 15              Tolerance  9.302000
# 16               Outdoors  3.662000

# %%
'''
data = json.load(open('ls_paz.json'))
la_paz = pd.DataFrame(data["categories"])

del la_paz['color']

la_paz2 = la_paz.transpose()
la_paz2['City'] = 'La Paz'

col_names = ['Housing', 'Cost of Living', 'Startups', 'Venture Capital', 'Travel Connectivity', 'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Education', 'Environmental Quality', 'Economy', 'Taxation', 'Internet Access', 'Leisure & Culture', 'Tolerance', 'Outdoors', 'City']
la_paz2.columns = [col_names]

la_paz3 = la_paz2.drop(la_paz2.index[0])

la_paz3

#asdjhakjds


'''
# Out:
# '\ndata = json.load(open(\'ls_paz.json\'))\nla_paz = pd.DataFrame(data["categories"])\n\ndel la_paz[\'color\']\n\nla_paz2 = la_paz.transpose()\nla_paz2[\'City\'] = \'La Paz\'\n\ncol_names = [\'Housing\', \'Cost of Living\', \'Startups\', \'Venture Capital\', \'Travel Connectivity\', \'Commute\', \'Business Freedom\', \'Safety\', \'Healthcare\', \'Education\', \'Environmental Quality\', \'Economy\', \'Taxation\', \'Internet Access\', \'Leisure & Culture\', \'Tolerance\', \'Outdoors\', \'City\']\nla_paz2.columns = [col_names]\n\nla_paz3 = la_paz2.drop(la_paz2.index[0])\n\nla_paz3\n\n#asdjhakjds\n\n\n'

# %%
data = json.load(open('florianopolis.json'))
florianopolis = pd.DataFrame(data["categories"])

del florianopolis['color']

col_names = ['Categories10', 'Florianopolis']
florianopolis.columns = [col_names]

florianopolis

#asdjhakjds
# Out:
#              Categories10 Florianopolis
# 0                 Housing      9.059500
# 1          Cost of Living      8.331000
# 2                Startups      1.000000
# 3         Venture Capital      0.000000
# 4     Travel Connectivity      0.683000
# 5                 Commute      4.787750
# 6        Business Freedom      2.781000
# 7                  Safety      6.525000
# 8              Healthcare      5.218667
# 9               Education      1.016500
# 10  Environmental Quality      4.944000
# 11                Economy      2.187000
# 12               Taxation      2.852500
# 13        Internet Access      3.185000
# 14      Leisure & Culture      5.330000
# 15              Tolerance      7.637500
# 16               Outdoors      5.751000

# %%
data = json.load(open('asunction.json'))
asuncion = pd.DataFrame(data["categories"])

del asuncion['color']

col_names = ['Categories11', 'Asuncion']
asuncion.columns = [col_names]

asuncion



#asdjhakjds
# Out:
#              Categories11  Asuncion
# 0                 Housing  9.226500
# 1          Cost of Living  9.295000
# 2                Startups  2.207000
# 3         Venture Capital  0.000000
# 4     Travel Connectivity  0.645000
# 5                 Commute  4.968750
# 6        Business Freedom  3.684000
# 7                  Safety  6.934500
# 8              Healthcare  4.891333
# 9               Education  0.000000
# 10  Environmental Quality  3.969000
# 11                Economy  4.109000
# 12               Taxation  8.423500
# 13        Internet Access  1.479000
# 14      Leisure & Culture  5.992000
# 15              Tolerance  7.051500
# 16               Outdoors  3.484500

# %%
frames = [asuncion, florianopolis, medellin, montevideo, porto_alegre, quito, rio_de_janeiro, santiago, caracas, sao_paulo, bogota, buenos_aires, curitiba]

scores = pd.concat(frames, axis = 1)

# %%
scores
# Out:
#              Categories11  Asuncion           Categories10 Florianopolis  \
# 0                 Housing  9.226500                Housing      9.059500
# 1          Cost of Living  9.295000         Cost of Living      8.331000
# 2                Startups  2.207000               Startups      1.000000
# 3         Venture Capital  0.000000        Venture Capital      0.000000
# 4     Travel Connectivity  0.645000    Travel Connectivity      0.683000
# 5                 Commute  4.968750                Commute      4.787750
# 6        Business Freedom  3.684000       Business Freedom      2.781000
# 7                  Safety  6.934500                 Safety      6.525000
# 8              Healthcare  4.891333             Healthcare      5.218667
# 9               Education  0.000000              Education      1.016500
# 10  Environmental Quality  3.969000  Environmental Quality      4.944000
# 11                Economy  4.109000                Economy      2.187000
# ...

# %%
del scores['Categories24']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Categories24'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
# ...

# %%
scores.to_csv('scores.csv')

# %%
scores
# Out:
#     Asuncion Florianopolis  Medellin Montevideo Porto Alegre     Quito  \
# 0   9.226500      9.059500  9.231500   8.183000     9.221000  9.016500
# 1   9.295000      8.331000  9.315000   6.197000     8.120000  7.822000
# 2   2.207000      1.000000  4.618000   2.863000     2.670500  2.857500
# 3   0.000000      0.000000  0.000000   2.205000     0.000000  0.000000
# 4   0.645000      0.683000  0.928000   1.183000     0.965500  0.890000
# 5   4.968750      4.787750  5.354500   5.288000     5.105000  4.789250
# 6   3.684000      2.781000  6.348667   7.944000     2.781000  3.021333
# 7   6.934500      6.525000  7.477000   5.973500     5.295500  6.969000
# 8   4.891333      5.218667  5.452333   6.364667     5.499667  5.324000
# 9   0.000000      1.016500  1.531000   1.690000     1.017000  0.000000
# 10  3.969000      4.944000  6.170750   4.545000     4.139750  4.176250
# 11  4.109000      2.187000  4.594500   4.416000     2.187000  3.885500
# ...

# %%
scores2 = scores.drop(scores.index[3])
scores2
# Out:
#     Asuncion Florianopolis  Medellin Montevideo Porto Alegre     Quito  \
# 0   9.226500      9.059500  9.231500   8.183000     9.221000  9.016500
# 1   9.295000      8.331000  9.315000   6.197000     8.120000  7.822000
# 2   2.207000      1.000000  4.618000   2.863000     2.670500  2.857500
# 4   0.645000      0.683000  0.928000   1.183000     0.965500  0.890000
# 5   4.968750      4.787750  5.354500   5.288000     5.105000  4.789250
# 6   3.684000      2.781000  6.348667   7.944000     2.781000  3.021333
# 7   6.934500      6.525000  7.477000   5.973500     5.295500  6.969000
# 8   4.891333      5.218667  5.452333   6.364667     5.499667  5.324000
# 9   0.000000      1.016500  1.531000   1.690000     1.017000  0.000000
# 10  3.969000      4.944000  6.170750   4.545000     4.139750  4.176250
# 11  4.109000      2.187000  4.594500   4.416000     2.187000  3.885500
# 12  8.423500      2.852500  1.851500   4.828500     2.852500  7.514000
# ...

# %%
scores3 = scores2.drop(scores.index[9])

# %%
scores3
# Out:
#     Asuncion Florianopolis  Medellin Montevideo Porto Alegre     Quito  \
# 0   9.226500      9.059500  9.231500   8.183000     9.221000  9.016500
# 1   9.295000      8.331000  9.315000   6.197000     8.120000  7.822000
# 2   2.207000      1.000000  4.618000   2.863000     2.670500  2.857500
# 4   0.645000      0.683000  0.928000   1.183000     0.965500  0.890000
# 5   4.968750      4.787750  5.354500   5.288000     5.105000  4.789250
# 6   3.684000      2.781000  6.348667   7.944000     2.781000  3.021333
# 7   6.934500      6.525000  7.477000   5.973500     5.295500  6.969000
# 8   4.891333      5.218667  5.452333   6.364667     5.499667  5.324000
# 10  3.969000      4.944000  6.170750   4.545000     4.139750  4.176250
# 11  4.109000      2.187000  4.594500   4.416000     2.187000  3.885500
# 12  8.423500      2.852500  1.851500   4.828500     2.852500  7.514000
# 13  1.479000      3.185000  4.148500   2.178500     2.196000  3.481500
# ...

# %%
scores3.to_csv('scores.csv')

scores3 = pd.read_csv('scores.csv')

scores3
# Out:
#     Unnamed: 0  Unnamed: 0.1  Asuncion  Florianopolis  Medellin  Montevideo  \
# 0            0             0  9.226500       9.059500  9.231500    8.183000
# 1            1             1  9.295000       8.331000  9.315000    6.197000
# 2            2             2  2.207000       1.000000  4.618000    2.863000
# 3            3             4  0.645000       0.683000  0.928000    1.183000
# 4            4             5  4.968750       4.787750  5.354500    5.288000
# 5            5             6  3.684000       2.781000  6.348667    7.944000
# 6            6             7  6.934500       6.525000  7.477000    5.973500
# 7            7             8  4.891333       5.218667  5.452333    6.364667
# 8            8            10  3.969000       4.944000  6.170750    4.545000
# 9            9            11  4.109000       2.187000  4.594500    4.416000
# 10          10            12  8.423500       2.852500  1.851500    4.828500
# ...

# %%
totals = scores3.sum()
totals
# Out:
# Asuncion                                                    76.3606
# Florianopolis                                               70.2729
# Medellin                                                    83.4832
# Montevideo                                                  79.7992
# Porto Alegre                                                71.1074
# Quito                                                       78.8748
# Rio de Janeiro                                              72.5533
# Santiago                                                    90.3067
# Caracas                                                     57.2071
# Categories        HousingCost of LivingStartupsTravel Connectivi...
# Sao Paulo                                                   76.8228
# Bogota                                                      84.3957
# Buenos Aires                                                77.7755
# Curitiba                                                    74.5613
# dtype: object

# %%
scores3

del scores3['Unnamed: 0']
del scores3['Unnamed: 0.1']

# %%
temp = pd.read_excel('temps2.xlsx')

# %%
temp
# Out:
#             Categories  Asuncion  Bogota  Buenos Aires  Caracas  Curitiba  \
# 0         avg_max_temp         8       2             2        8         2
# 1         avg_min_temp         8       2             8        8         2
# 2         hours_of_sun         8       2             8        8         2
# 3  rain_days_per_month         8       2             8        8         2
#
#    Florianopolis  Medellin  Montevideo  Porto Alegre  Quito  Rio de Janeiro  \
# 0              8         8           2             8      2               8
# 1              8         8           2             8      2               8
# 2              2         2           8             8      2               2
# 3              2         2           8             2      2               2
#
#    Santiago  Sao Paulo
# 0         2          8
# 1         2          8
# 2         8          2
# 3         8          2

# %%
temp[['Asuncion', 'Bogota', 'Buenos Aires', 'Caracas', 'Curitiba', 'Florianopolis', 'Medellin', 'Montevideo', 'Porto Alegre', 'Quito', 'Rio de Janeiro', 'Santiago', 'Sao Paulo']]

# %%
col_names = ['Categories', 'Asuncion', 'Bogota', 'Buenos Aires', 'Caracas', 'Curitiba', 'Florianopolis', 'Medellin', 'Montevideo', 'Porto Alegre', 'Quito', 'Rio de Janeiro', 'Santiago', 'Sao Paulo']

# %%
scores4 = scores3[col_names]

# %%
scores4
# Out:
#                Categories  Asuncion    Bogota  Buenos Aires   Caracas  \
# 0                 Housing  9.226500  9.027500      8.812000  4.902500
# 1          Cost of Living  9.295000  9.080000      7.764000  9.820000
# 2                Startups  2.207000  5.708500      4.673000  3.053500
# 3     Travel Connectivity  0.645000  1.889000      3.770000  1.323500
# 4                 Commute  4.968750  4.964000      4.923500  4.544250
# 5        Business Freedom  3.684000  6.348667      4.045333  1.000000
# 6                  Safety  6.934500  6.222000      6.039500  5.221000
# 7              Healthcare  4.891333  5.139000      6.106667  4.241333
# 8   Environmental Quality  3.969000  4.347500      4.869000  2.272500
# 9                 Economy  4.109000  4.594500      2.884000  1.978000
# 10               Taxation  8.423500  1.851500      1.568000  4.180000
# 11        Internet Access  1.479000  2.976000      1.527500  1.641500
# ...

# %%
frames = [temp, scores4]
scores.shape
# Out:
# (17, 14)

# %%
total = pd.concat(frames, axis = 0)
total
# Out:
#                Categories  Asuncion    Bogota  Buenos Aires   Caracas  \
# 0            avg_max_temp  8.000000  2.000000      2.000000  8.000000
# 1            avg_min_temp  8.000000  2.000000      8.000000  8.000000
# 2            hours_of_sun  8.000000  2.000000      8.000000  8.000000
# 3     rain_days_per_month  8.000000  2.000000      8.000000  8.000000
# 0                 Housing  9.226500  9.027500      8.812000  4.902500
# 1          Cost of Living  9.295000  9.080000      7.764000  9.820000
# 2                Startups  2.207000  5.708500      4.673000  3.053500
# 3     Travel Connectivity  0.645000  1.889000      3.770000  1.323500
# 4                 Commute  4.968750  4.964000      4.923500  4.544250
# 5        Business Freedom  3.684000  6.348667      4.045333  1.000000
# 6                  Safety  6.934500  6.222000      6.039500  5.221000
# 7              Healthcare  4.891333  5.139000      6.106667  4.241333
# ...

# %%
total.to_csv('total.csv')

# %%
scores.dtypes
# Out:
# Asuncion          float64
# Florianopolis     float64
# Medellin          float64
# Montevideo        float64
# Porto Alegre      float64
# Quito             float64
# Rio de Janeiro    float64
# Santiago          float64
# Caracas           float64
# Categories         object
# Sao Paulo         float64
# Bogota            float64
# Buenos Aires      float64
# Curitiba          float64
# dtype: object

# %%
temp

temp['Asuncion']=temp.Asuncion.astype(float)
temp['Bogota']=temp.Bogota.astype(float)
temp['Buenos Aires']=temp['Buenos Aires'].astype(float)
temp['Caracas']=temp.Caracas.astype(float)
temp['Curitiba']=temp.Curitiba.astype(float)
temp['Florianopolis']=temp.Florianopolis.astype(float)
temp['Medellin']=temp.Medellin.astype(float)
temp['Montevideo']=temp.Montevideo.astype(float)
temp['Porto Alegre']=temp['Porto Alegre'].astype(float)
temp['Quito']=temp.Quito.astype(float)
temp['Rio de Janeiro']=temp['Rio de Janeiro'].astype(float)
temp['Santiago']=temp.Caracas.astype(float)
temp['Sao Paulo']=temp['Sao Paulo'].astype(float)

temp.dtypes
# Out:
# Categories         object
# Asuncion          float64
# Bogota            float64
# Buenos Aires      float64
# Caracas           float64
# Curitiba          float64
# Florianopolis     float64
# Medellin          float64
# Montevideo        float64
# Porto Alegre      float64
# Quito             float64
# Rio de Janeiro    float64
# Santiago          float64
# Sao Paulo         float64
# dtype: object

# %%
scores.sum()
# Out:
# Asuncion                                                    76.3606
# Florianopolis                                               71.2894
# Medellin                                                    85.0143
# Montevideo                                                  83.6942
# Porto Alegre                                                72.1244
# Quito                                                       78.8748
# Rio de Janeiro                                              75.9848
# Santiago                                                    93.9482
# Caracas                                                     57.2071
# Categories        HousingCost of LivingStartupsVenture CapitalTr...
# Sao Paulo                                                   82.1798
# Bogota                                                      87.1887
# Buenos Aires                                                81.5075
# Curitiba                                                    77.7258
# dtype: object

# %%
sum_cities = total.sum()

# %%
sum_cities.to_csv('sum_cities.csv')
# Out:
# /Users/louise/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %%
total2 = total.transpose()
total2
# Out:
#                           0             1             2                    3   \
# Categories      avg_max_temp  avg_min_temp  hours_of_sun  rain_days_per_month
# Asuncion                   8             8             8                    8
# Bogota                     2             2             2                    2
# Buenos Aires               2             8             8                    8
# Caracas                    8             8             8                    8
# Curitiba                   2             2             2                    2
# Florianopolis              8             8             2                    2
# Medellin                   8             8             2                    2
# Montevideo                 2             2             8                    8
# Porto Alegre               8             8             8                    2
# Quito                      2             2             2                    2
# ...

# %%
total2.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# 12    object
# 13    object
# 14    object
# dtype: object

# %%
col_names = ['Avg max temp', 'Avg min temp', 'Hours of sun', 'Rain days per month', 'Housing', 'Cost of Living', 'Startups', 'Travel Connectivity', 'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Environmental Quality', 'Economy', 'Taxation', 'Internet Access', 'Leisure & Culture', 'Tolerance', 'Outdoors']

total2.columns = [col_names]

total2
# Out:
#                 Avg max temp  Avg min temp  Hours of sun  Rain days per month  \
# Categories      avg_max_temp  avg_min_temp  hours_of_sun  rain_days_per_month
# Asuncion                   8             8             8                    8
# Bogota                     2             2             2                    2
# Buenos Aires               2             8             8                    8
# Caracas                    8             8             8                    8
# Curitiba                   2             2             2                    2
# Florianopolis              8             8             2                    2
# Medellin                   8             8             2                    2
# Montevideo                 2             2             8                    8
# Porto Alegre               8             8             8                    2
# Quito                      2             2             2                    2
# ...

# %%
total3 = total2.drop(total2.index[0])
total3
# Out:
#                Avg max temp Avg min temp Hours of sun Rain days per month  \
# Asuncion                  8            8            8                   8
# Bogota                    2            2            2                   2
# Buenos Aires              2            8            8                   8
# Caracas                   8            8            8                   8
# Curitiba                  2            2            2                   2
# Florianopolis             8            8            2                   2
# Medellin                  8            8            2                   2
# Montevideo                2            2            8                   8
# Porto Alegre              8            8            8                   2
# Quito                     2            2            2                   2
# Rio de Janeiro            8            8            2                   2
# Santiago                  8            8            8                   8
# ...

# %%
total3.corr()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
total = pd.read_csv('total.csv')
total

del total['Unnamed: 0']
total
# Out:
#                Categories  Asuncion    Bogota  Buenos Aires   Caracas  \
# 0            avg_max_temp  8.000000  2.000000      2.000000  8.000000
# 1            avg_min_temp  8.000000  2.000000      8.000000  8.000000
# 2            hours_of_sun  8.000000  2.000000      8.000000  8.000000
# 3     rain_days_per_month  8.000000  2.000000      8.000000  8.000000
# 4                 Housing  9.226500  9.027500      8.812000  4.902500
# 5          Cost of Living  9.295000  9.080000      7.764000  9.820000
# 6                Startups  2.207000  5.708500      4.673000  3.053500
# 7     Travel Connectivity  0.645000  1.889000      3.770000  1.323500
# 8                 Commute  4.968750  4.964000      4.923500  4.544250
# 9        Business Freedom  3.684000  6.348667      4.045333  1.000000
# 10                 Safety  6.934500  6.222000      6.039500  5.221000
# 11             Healthcare  4.891333  5.139000      6.106667  4.241333
# ...

# %%
del total['Categories']

# %%
#del total['Categories']

total

mean_values = total.mean()

mean_values.to_csv('means.csv')
# Out:
# /Users/louise/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   import sys

# %%
total_trans2 = total.transpose()
total_trans2
# Out:
#                   0    1    2    3       4      5       6       7        8  \
# Asuncion        8.0  8.0  8.0  8.0  9.2265  9.295  2.2070  0.6450  4.96875
# Bogota          2.0  2.0  2.0  2.0  9.0275  9.080  5.7085  1.8890  4.96400
# Buenos Aires    2.0  8.0  8.0  8.0  8.8120  7.764  4.6730  3.7700  4.92350
# Caracas         8.0  8.0  8.0  8.0  4.9025  9.820  3.0535  1.3235  4.54425
# Curitiba        2.0  2.0  2.0  2.0  9.4295  8.433  2.9120  0.8900  4.95025
# Florianopolis   8.0  8.0  2.0  2.0  9.0595  8.331  1.0000  0.6830  4.78775
# Medellin        8.0  8.0  2.0  2.0  9.2315  9.315  4.6180  0.9280  5.35450
# Montevideo      2.0  2.0  8.0  8.0  8.1830  6.197  2.8630  1.1830  5.28800
# Porto Alegre    8.0  8.0  8.0  2.0  9.2210  8.120  2.6705  0.9655  5.10500
# Quito           2.0  2.0  2.0  2.0  9.0165  7.822  2.8575  0.8900  4.78925
# Rio de Janeiro  8.0  8.0  2.0  2.0  8.3200  7.751  4.8230  1.4930  4.55325
# ...

# %%
col_names = ['Avg max temp', 'Avg min temp', 'Hours of sun', 'Rain days per month', 'Housing', 'Cost of Living', 'Startups', 'Travel Connectivity', 'Commute', 'Business Freedom', 'Safety', 'Healthcare', 'Environmental Quality', 'Economy', 'Taxation', 'Internet Access', 'Leisure & Culture', 'Tolerance', 'Outdoors']

total_trans2.columns = [col_names]

# %%
total_trans2
# Out:
#                Avg max temp Avg min temp Hours of sun Rain days per month  \
# Asuncion                8.0          8.0          8.0                 8.0
# Bogota                  2.0          2.0          2.0                 2.0
# Buenos Aires            2.0          8.0          8.0                 8.0
# Caracas                 8.0          8.0          8.0                 8.0
# Curitiba                2.0          2.0          2.0                 2.0
# Florianopolis           8.0          8.0          2.0                 2.0
# Medellin                8.0          8.0          2.0                 2.0
# Montevideo              2.0          2.0          8.0                 8.0
# Porto Alegre            8.0          8.0          8.0                 2.0
# Quito                   2.0          2.0          2.0                 2.0
# Rio de Janeiro          8.0          8.0          2.0                 2.0
# Santiago                8.0          8.0          8.0                 8.0
# ...

# %%
total_trans2.to_csv('transformed.csv')

# %%
total_trans2.dtypes
# Out:
# Avg max temp             float64
# Avg min temp             float64
# Hours of sun             float64
# Rain days per month      float64
# Housing                  float64
# Cost of Living           float64
# Startups                 float64
# Travel Connectivity      float64
# Commute                  float64
# Business Freedom         float64
# Safety                   float64
# Healthcare               float64
# Environmental Quality    float64
# Economy                  float64
# Taxation                 float64
# Internet Access          float64
# Leisure & Culture        float64
# Tolerance                float64
# Outdoors                 float64
# dtype: object

# %%
corr = total_trans.corr()

corr.to_csv('correlations.csv')

corr
# Out:
#                       Avg max temp Avg min temp Hours of sun  \
# Avg max temp              1.000000     0.843274     0.097590
# Avg min temp              0.843274     1.000000     0.282889
# Hours of sun              0.097590     0.282889     1.000000
# Rain days per month      -0.025000     0.184466     0.853913
# Housing                  -0.242465    -0.216553    -0.351079
# Cost of Living            0.311229     0.245599    -0.155054
# Startups                  0.029872     0.113955    -0.140688
# Travel Connectivity      -0.206534     0.217515     0.255358
# Commute                  -0.111865    -0.125382     0.364114
# Business Freedom         -0.218360    -0.247037     0.125591
# Safety                   -0.069019    -0.101519    -0.119505
# Healthcare               -0.224747    -0.094845     0.289006
# Environmental Quality    -0.407949    -0.377142    -0.261888
# Economy                  -0.331960    -0.395333     0.048171
# ...

# %%
sums = total_trans.sum()

# %%
sums
# Out:
# Avg max temp              74.000000
# Avg min temp              80.000000
# Hours of sun              62.000000
# Rain days per month       56.000000
# Housing                  111.127000
# Cost of Living           106.988000
# Startups                  50.239000
# Travel Connectivity       19.461000
# Commute                   64.191500
# Business Freedom          55.317667
# Safety                    80.159000
# Healthcare                71.507667
# Environmental Quality     57.695250
# Economy                   41.121500
# Taxation                  53.402000
# Internet Access           32.683000
# Leisure & Culture         84.271500
# Tolerance                 99.352000
# Outdoors                  66.004500
# dtype: float64

# %%
sum_cities = pd.read_csv('sum_cities.csv')

# %%
sum_cities
# Out:
#         Categories  \
# 0         Asuncion
# 1           Bogota
# 2     Buenos Aires
# 3          Caracas
# 4         Curitiba
# 5    Florianopolis
# 6         Medellin
# 7       Montevideo
# 8     Porto Alegre
# 9            Quito
# 10  Rio de Janeiro
# 11        Santiago
# 12       Sao Paulo
#
#     avg_max_tempavg_min_temphours_of_sunrain_days_per_monthHousingCost of LivingStartupsTravel ConnectivityCommuteBusiness FreedomSafetyHealthcareEnvironmental QualityEconomyTaxationInternet AccessLeisure & CultureToleranceOutdoors
# 0                                          108.360583
# 1                                           92.395667
# 2                                          103.775500
# 3                                           89.207083
# 4                                           82.561333
# 5                                           90.272917
# 6                                          103.483250
# 7                                           99.799167
# ...
